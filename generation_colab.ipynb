# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd gdrive/MyDrive/Project-pytorch-ddpm
# Out:
# /content/gdrive/MyDrive/Project-pytorch-ddpm

# %%
# !ls -a
# Out:
# config		generation_colab.ipynb	main.py      requirements.txt
# data		images			model.py     sandbox.py
# diffusion.py	LICENSE			__pycache__  score
# fine_tuning.py	logs			Readme.md    stats

# %%
# !python main.py --flagfile ./logs/DDPM_CIFAR10_EPS/flagfile.txt --notrain --eval --noema
# Out:
# cuda
# generating images: 100% 2/2 [10:09<00:00, 304.75s/it]
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Model     : IS: 5.546(0.381), FID: 93.994

# %%
img_path = './logs/DDPM_CIFAR10_EPS/samples.png'
img = Image.open(img_path)
plt.figure(figsize = (10,10))
plt.imshow(img)

# %%
# !python fine_tuning.py --flagfile ./logs/DDPM_CIFAR10_EPS/flagfile.txt --total_steps=300 --save_step=100 --sample_step=100 --nofrom_scratch
# Out:
# cuda
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Model params: 34.21 M
#  47% 477/1010 [58:44<1:02:37,  7.05s/it, loss=0.036]
