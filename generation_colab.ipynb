# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 6.6 MB/s eta 0:00:00
# ...

# %%
# %cd gdrive/MyDrive/Project-pytorch-ddpm
# Out:
# /content/gdrive/MyDrive/Project-pytorch-ddpm

# %%
# !ls -a
# Out:
# config		generation_colab.ipynb	LICENSE   Readme.md
# data		.git			logs	  requirements.txt
# diffusion.py	.gitignore		main.py   score
# fine_tuning.py	images			model.py  stats

# %%
# !python main.py --flagfile ./logs/DDPM_CIFAR10_EPS/flagfile.txt --notrain --eval --noema
# Out:
# Device used: cuda
# generating images:   1% 2/391 [10:32<34:10:37, 316.29s/it]
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/Project-pytorch-ddpm/main.py", line 312, in <module>
#   File "/usr/local/lib/python3.9/dist-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.9/dist-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/content/gdrive/MyDrive/Project-pytorch-ddpm/main.py", line 306, in main
#     eval(FLAGS.ema)
#   File "/content/gdrive/MyDrive/Project-pytorch-ddpm/main.py", line 281, in eval
#     (IS, IS_std), FID, samples = evaluate(sampler, model)
#   File "/content/gdrive/MyDrive/Project-pytorch-ddpm/main.py", line 98, in evaluate
#     batch_images = sampler(x_T.to(device)).cpu()
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
# ...

# %%
img_path = './logs/DDPM_CIFAR10_EPS/samples.png'
img = Image.open(img_path)
plt.figure(figsize = (10,10))
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-09abc2926d9b> in <module>
#       1 img_path = './logs/DDPM_CIFAR10_EPS/samples.png'
# ----> 2 img = Image.open(img_path)
#       3 plt.figure(figsize = (10,10))
#       4 plt.imshow(img)
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: './logs/DDPM_CIFAR10_EPS/samples.png'

# %%
# !python fine_tuning.py --flagfile ./logs/DDPM_CIFAR10_EPS/flagfile.txt --total_steps=300 --save_step=100 --sample_step=100 --from_scratch
# Out:
# Device used: cuda
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Model params: 34.21 M
#   0% 0/300 [00:03<?, ?it/s, loss=0.040]./logs/DDPM_CIFAR10_EPS/sample_fine_tune/0.png
#  33% 100/300 [05:02<04:52,  1.46s/it, loss=0.027]./logs/DDPM_CIFAR10_EPS/sample_fine_tune/100.png
#  67% 200/300 [10:00<02:27,  1.48s/it, loss=0.031]./logs/DDPM_CIFAR10_EPS/sample_fine_tune/200.png
# 100% 300/300 [14:58<00:00,  2.99s/it, loss=0.028]
# generating images:   0% 1/391 [08:43<56:40:42, 523.19s/it]
# Traceback (most recent call last):
# ...

# %%
# !python fine_tuning.py --flagfile ./logs/DDPM_CIFAR10_EPS/flagfile.txt --total_steps=300 --save_step=100 --sample_step=100 --nofrom_scratch --nogeneration
# Out:
# Device used: cuda
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Model params: 34.21 M
#   0% 0/300 [00:02<?, ?it/s, loss=0.029]./logs/DDPM_CIFAR10_EPS/sample_fine_tune/598.png
#  33% 100/300 [04:50<04:32,  1.36s/it, loss=0.040]./logs/DDPM_CIFAR10_EPS/sample_fine_tune/698.png
#  67% 200/300 [09:40<02:12,  1.32s/it, loss=0.024]./logs/DDPM_CIFAR10_EPS/sample_fine_tune/798.png
# 100% 300/300 [14:31<00:00,  2.90s/it, loss=0.021]
